# %% [markdown]
# ### Data Types

# %%
x=10
type(x)
# Out:
# int

# %%
x=10.5
type(x)
# Out:
# float

# %%
x="python"
type(x)
# Out:
# str

# %%
x=True
type(x)
# Out:
# bool

# %%
x=False
type(x)
# Out:
# bool

# %%
x=1-2j
type(x)
# Out:
# complex
